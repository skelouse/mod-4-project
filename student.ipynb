# %% [markdown]
# ## Final Project Submission
#
# * Student name: Sam Stoltenberg
# * Student pace: full time
# * Scheduled project review date/time: 11/10/2020 | 3:30PM
# * Instructor name: James Irving
# * Blog post URL: https://skelouse.github.io/faster_mapping_with_folium

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Final-Project-Submission" data-toc-modified-id="Final-Project-Submission-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Final Project Submission</a></span></li><li><span><a href="#Introduction" data-toc-modified-id="Introduction-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Importing-Data-and-Libraries" data-toc-modified-id="Importing-Data-and-Libraries-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Importing Data and Libraries</a></span><ul class="toc-item"><li><span><a href="#Style" data-toc-modified-id="Style-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Style</a></span></li><li><span><a href="#Setting-seeds-for-reproducibility" data-toc-modified-id="Setting-seeds-for-reproducibility-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Setting seeds for reproducibility</a></span></li><li><span><a href="#Library-imports" data-toc-modified-id="Library-imports-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Library imports</a></span><ul class="toc-item"><li><span><a href="#Scikit-learn" data-toc-modified-id="Scikit-learn-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Scikit-learn</a></span></li><li><span><a href="#Tensorflow" data-toc-modified-id="Tensorflow-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Tensorflow</a></span></li></ul></li><li><span><a href="#Enabling-GPU,-and-confirming-it-is-working" data-toc-modified-id="Enabling-GPU,-and-confirming-it-is-working-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Enabling GPU, and confirming it is working</a></span></li><li><span><a href="#Importing-the-data" data-toc-modified-id="Importing-the-data-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Importing the data</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Removing-no-emotion" data-toc-modified-id="Removing-no-emotion-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Removing no emotion</a></span></li><li><span><a href="#Checking-and-filling-null-values" data-toc-modified-id="Checking-and-filling-null-values-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Checking and filling null values</a></span></li><li><span><a href="#class-balance" data-toc-modified-id="class-balance-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>class balance</a></span></li><li><span><a href="#Limit-this-to-just-iphone-/-android-vs-all-of-it" data-toc-modified-id="Limit-this-to-just-iphone-/-android-vs-all-of-it-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Limit this to just iphone / android vs all of it</a></span></li><li><span><a href="#Making-Word2Vec" data-toc-modified-id="Making-Word2Vec-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Making Word2Vec</a></span></li><li><span><a href="#Using-Word2Vec" data-toc-modified-id="Using-Word2Vec-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Using Word2Vec</a></span></li><li><span><a href="#Generating-a-Word-Cloud" data-toc-modified-id="Generating-a-Word-Cloud-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Generating a Word Cloud</a></span><ul class="toc-item"><li><span><a href="#Generating" data-toc-modified-id="Generating-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Generating</a></span></li></ul></li></ul></li><li><span><a href="#Scrubbing-the-Data-for-Modeling" data-toc-modified-id="Scrubbing-the-Data-for-Modeling-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Scrubbing the Data for Modeling</a></span><ul class="toc-item"><li><span><a href="#Mapping-emotion-positive=1,-negative=0" data-toc-modified-id="Mapping-emotion-positive=1,-negative=0-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Mapping emotion positive=1, negative=0</a></span></li><li><span><a href="#Train-Test-Split" data-toc-modified-id="Train-Test-Split-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Train Test Split</a></span></li><li><span><a href="#Fix-class-imbalance-for-training-data" data-toc-modified-id="Fix-class-imbalance-for-training-data-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Fix class imbalance for training data</a></span></li><li><span><a href="#Vectorize" data-toc-modified-id="Vectorize-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Vectorize</a></span></li></ul></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Modeling</a></span><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Functions</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Random Forest</a></span><ul class="toc-item"><li><span><a href="#Vanilla-Model" data-toc-modified-id="Vanilla-Model-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Vanilla Model</a></span></li><li><span><a href="#Tuned-Model" data-toc-modified-id="Tuned-Model-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Tuned Model</a></span></li></ul></li><li><span><a href="#Gradient-Boosting-Classifier" data-toc-modified-id="Gradient-Boosting-Classifier-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Gradient Boosting Classifier</a></span><ul class="toc-item"><li><span><a href="#Vanilla-model" data-toc-modified-id="Vanilla-model-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Vanilla model</a></span></li><li><span><a href="#Tuned-Model" data-toc-modified-id="Tuned-Model-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>Tuned Model</a></span></li></ul></li><li><span><a href="#KNN-Classifier" data-toc-modified-id="KNN-Classifier-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>KNN Classifier</a></span><ul class="toc-item"><li><span><a href="#Vanilla-model" data-toc-modified-id="Vanilla-model-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>Vanilla model</a></span></li><li><span><a href="#Tuned-Model" data-toc-modified-id="Tuned-Model-6.4.2"><span class="toc-item-num">6.4.2&nbsp;&nbsp;</span>Tuned Model</a></span></li></ul></li><li><span><a href="#SVC-Classifier" data-toc-modified-id="SVC-Classifier-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>SVC Classifier</a></span><ul class="toc-item"><li><span><a href="#Vanilla-model" data-toc-modified-id="Vanilla-model-6.5.1"><span class="toc-item-num">6.5.1&nbsp;&nbsp;</span>Vanilla model</a></span></li><li><span><a href="#Tuned-Model" data-toc-modified-id="Tuned-Model-6.5.2"><span class="toc-item-num">6.5.2&nbsp;&nbsp;</span>Tuned Model</a></span></li></ul></li><li><span><a href="#Adaboost-Classifier" data-toc-modified-id="Adaboost-Classifier-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Adaboost Classifier</a></span><ul class="toc-item"><li><span><a href="#Get-data" data-toc-modified-id="Get-data-6.6.1"><span class="toc-item-num">6.6.1&nbsp;&nbsp;</span>Get data</a></span></li><li><span><a href="#Vanilla-model" data-toc-modified-id="Vanilla-model-6.6.2"><span class="toc-item-num">6.6.2&nbsp;&nbsp;</span>Vanilla model</a></span></li><li><span><a href="#Tuned-Model" data-toc-modified-id="Tuned-Model-6.6.3"><span class="toc-item-num">6.6.3&nbsp;&nbsp;</span>Tuned Model</a></span></li></ul></li><li><span><a href="#Stacking-classifier" data-toc-modified-id="Stacking-classifier-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Stacking classifier</a></span><ul class="toc-item"><li><span><a href="#Vanilla-model" data-toc-modified-id="Vanilla-model-6.7.1"><span class="toc-item-num">6.7.1&nbsp;&nbsp;</span>Vanilla model</a></span></li><li><span><a href="#Tuned-Model" data-toc-modified-id="Tuned-Model-6.7.2"><span class="toc-item-num">6.7.2&nbsp;&nbsp;</span>Tuned Model</a></span></li></ul></li><li><span><a href="#Voting-Classfier?" data-toc-modified-id="Voting-Classfier?-6.8"><span class="toc-item-num">6.8&nbsp;&nbsp;</span>Voting Classfier?</a></span><ul class="toc-item"><li><span><a href="#Vanilla-Model" data-toc-modified-id="Vanilla-Model-6.8.1"><span class="toc-item-num">6.8.1&nbsp;&nbsp;</span>Vanilla Model</a></span></li><li><span><a href="#Tuned-Model" data-toc-modified-id="Tuned-Model-6.8.2"><span class="toc-item-num">6.8.2&nbsp;&nbsp;</span>Tuned Model</a></span></li></ul></li></ul></li><li><span><a href="#Modeling-Conclusion" data-toc-modified-id="Modeling-Conclusion-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Modeling Conclusion</a></span><ul class="toc-item"><li><span><a href="#Feature-Importance" data-toc-modified-id="Feature-Importance-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Feature Importance</a></span></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Conclusion</a></span><ul class="toc-item"><li><span><a href="#Future-Work" data-toc-modified-id="Future-Work-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Future Work</a></span></li></ul></li><li><span><a href="#Appendix-(-Experimental-)" data-toc-modified-id="Appendix-(-Experimental-)-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Appendix ( Experimental )</a></span><ul class="toc-item"><li><span><a href="#Modeling-Neural-Network" data-toc-modified-id="Modeling-Neural-Network-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Modeling Neural Network</a></span><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-9.1.1"><span class="toc-item-num">9.1.1&nbsp;&nbsp;</span>Functions</a></span></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-9.1.2"><span class="toc-item-num">9.1.2&nbsp;&nbsp;</span>Modeling</a></span></li></ul></li><li><span><a href="#Using-Glove" data-toc-modified-id="Using-Glove-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Using Glove</a></span><ul class="toc-item"><li><span><a href="#Model-with-glove" data-toc-modified-id="Model-with-glove-9.2.1"><span class="toc-item-num">9.2.1&nbsp;&nbsp;</span>Model with glove</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Introduction
#
# > Here we will be trying different models and types of networks to predict whether a tweet is positive or negative towards a certain product.
#
#
# > * Which model will perform best?
# > * Which aspects of a phone should the company improve
# > * What can androids or iphones improve in their products to reduce negative feedback?
#
# > The data comes from CrowdFlower via [data.world](https://data.world/crowdflower/brands-and-product-emotions). Human raters rated the sentiment in over 9,000 Tweets as positive, negative, or neither, it has the following columns:
# > * **tweet_text**
# > * **emotion_in_tweet_is_directed_at**
# > * **is_there_an_emotion_directed_at_a_brand_or_product**
# >
# > **Which I have renamed to:**
# > * **text**  The text of the tweet
# > * **directed_at**  Which product the emotion of the tweet is directed at
# > * **emotion** Positive, negative or neither emotion
#
# > This project was done with the OSEMN Process
# >- **O**btain
# >- **S**crub
# >- **E**xplore
# >- **M**odel
# >- I**N**terpret

# %% [markdown]
# ## Importing Data and Libraries
# > * Add notebook style
# > * Set seeds to 42 so anyone can get the same results
# > * Import libraries
# > * Enable GPU
# > * Import the data from data file

# %%
RETEST = False  # Change to True to retest the grid searches
USE_GPU = True  # Change to False to use CPU instead of GPU

# %% [markdown]
# ### Style

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib as mpl
mpl.rcParams['axes.titlesize']='xx-large'
mpl.rcParams['xtick.labelsize'] = 13
mpl.rcParams['ytick.labelsize'] = 13
mpl.rcParams['axes.labelsize'] = 16

# Styling notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("./styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>.shadowbox {
#     width: 40em;
#     border: 1px solid #333;
#     box-shadow: 8px 8px 5px #444;
#     padding: 8px 12px;
#     background-image: linear-gradient(180deg, black, rgb(214, 94, 94));
#     color: rgba(243, 218, 74, 0.801);
#     line-height: 25px;
#     position: static;
# }
#
# h2 {
#     width: 45em;
#     border: 1.5px solid #333;
#     /*box-shadow: 8px 8px 5px #444;*/
#     padding: 8px 12px;
#     background-image: linear-gradient(180deg, #fff, rgb(36, 29, 29));
#     position: static;
# }
#
# h3 {
#     width: 45em;
#     border: 1px solid #333;
#     /*box-shadow: 8px 8px 5px #444;*/
#     padding: 8px 12px;
#     background-image: linear-gradient(180deg, #fff, rgb(36, 29, 29));
#     position: relative;
#     right: -13px;
# }
#
# h4 {
#     width: 45em;
#     border: 0.5px solid #333;
#     /*box-shadow: 8px 8px 5px #444;*/
#     padding: 8px 12px;
#     background-image: linear-gradient(180deg, #fff, rgb(36, 29, 29));
#     position: relative;
# ...

# %% [markdown]
# ### Setting seeds for reproducibility

# %%
import numpy as np
np.random.seed(42)

import tensorflow as tf
tf.random.set_seed(42)

# %% [markdown]
# ### Library imports

# %%
import os
import string
import nltk
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from nltk import word_tokenize, FreqDist
from nltk.corpus import stopwords
from gensim.models import Word2Vec, KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec
from wordcloud import WordCloud, ImageColorGenerator
from PIL import Image

# %% [markdown]
# #### Scikit-learn

# %%
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier, StackingClassifier, \
                             AdaBoostClassifier, GradientBoostingClassifier, \
                             VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import confusion_matrix, plot_confusion_matrix, \
                            classification_report
from sklearn.utils import resample

# %% [markdown]
# #### Tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, Dropout, LSTM, Embedding, Input, \
                                    Bidirectional, LeakyReLU, ELU
from tensorflow.keras.regularizers import l2, l1
from tensorflow.keras.preprocessing import text, sequence

# %% [markdown]
# ### Enabling GPU, and confirming it is working

# %%
if USE_GPU:
    # Enable GPU
    physical_devices = tf.config.list_physical_devices('GPU')
    tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
    os.environ["TF_FORCE_GPU_ALLOW_GROWTH"]="true"

    # Show GPU
    print("Using GPU")
    print(tf.config.list_physical_devices('GPU'))
else:
    print("Using CPU")
# Out:
# Using GPU
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Importing the data

# %%
data_file = 'data/tweet.csv'
df = pd.read_csv(data_file, encoding='latin-1')
display(df.head())
df.columns = ['text', 'directed_at', 'emotion']
df.head()
# Out:
#                                           tweet_text  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs twe...
# 1  @jessedee Know about @fludapp ? Awesome iPad/i...
# 2  @swonderlin Can not wait for #iPad 2 also. The...
# 3  @sxsw I hope this year's festival isn't as cra...
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa M...
#
#   emotion_in_tweet_is_directed_at  \
# 0                          iPhone
# 1              iPad or iPhone App
# 2                            iPad
# 3              iPad or iPhone App
# 4                          Google
#
#   is_there_an_emotion_directed_at_a_brand_or_product
# 0                                   Negative emotion
# 1                                   Positive emotion
# 2                                   Positive emotion
# 3                                   Negative emotion
# 4                                   Positive emotion
#                                                 text         directed_at  \
# ...

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Removing no emotion
#
# > Removing **no emotion** and **I can't tell** to make a multi class problem into a binary classification problem.

# %%
df['emotion'].value_counts(normalize=True)
# Out:
# No emotion toward brand or product    0.592654
# Positive emotion                      0.327505
# Negative emotion                      0.062686
# I can't tell                          0.017156
# Name: emotion, dtype: float64

# %%
df = df.loc[(df['emotion'] == 'Positive emotion') |
            (df['emotion'] == 'Negative emotion')]

# %% [markdown]
# ### Checking and filling null values

# %%
df.isna().sum()
# Out:
# text             0
# directed_at    357
# emotion          0
# dtype: int64

# %%
df['directed_at'] = df['directed_at'].fillna('unknown')

# %% [markdown]
# ### class balance

# %%
df['emotion'].value_counts(1)
# Out:
# Positive emotion    0.839346
# Negative emotion    0.160654
# Name: emotion, dtype: float64

# %% [markdown]
# ### Limit this to just iphone / android vs all of it

# %%
df1 = df.copy()
df1['brand'] = df1['directed_at'].map({"Other Apple product or service": "unknown",
                                        "Android App": "Android",
                                        "iPad": "Apple",
                                        "iPad or iPhone App": "Apple",
                                        "Google": "unknown",
                                        "Other Google product or service": "unknown",
                                        "iPhone": "Apple"})

df1 = df1.loc[(df1['brand'] == 'Apple') |
              (df1['brand'] == "Android")]
print(len(df1.loc[df1['brand'] == 'Android']), len(df1.loc[df1['brand'] == 'Apple']))
x, y = 'brand', 'emotion'
fig, ax = plt.subplots(figsize=(10, 8))
df1 = df1.groupby(x)[y].value_counts(1)
df1 = df1.mul(100)
df1 = df1.rename('percent').reset_index().sort_values(by='percent', ascending=False)
g = sns.barplot(x=x, y='percent', hue=y, data=df1, ax=ax)
ax.set_title('Positive vs Negative emotion to different products')
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2,
            height+1,
            ("%s"%round(height, 2) + '%'),
            ha='center')
# Out:
# 80 1665

# %%
len(df1.loc[df1['brand'] == 'Apple']), len(df1.loc[df1['brand'] == 'Android'])
# Out:
# (2, 2)

# %% [markdown]
# ### Making Word2Vec

# %%
df.head()
# Out:
#                                                 text         directed_at  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs twe...              iPhone
# 1  @jessedee Know about @fludapp ? Awesome iPad/i...  iPad or iPhone App
# 2  @swonderlin Can not wait for #iPad 2 also. The...                iPad
# 3  @sxsw I hope this year's festival isn't as cra...  iPad or iPhone App
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa M...              Google
#
#             emotion
# 0  Negative emotion
# 1  Positive emotion
# 2  Positive emotion
# 3  Negative emotion
# 4  Positive emotion

# %%
stop_list = stopwords.words('english')
stop_list += string.punctuation

# stop_list2 = ['sxsw', 'iphone', 'apple', 'ipad2', 'android',
#               'rt mention', 'mention', 'google', 'sxsw rt',
#               'sxsw link', 'link sxsw', 'ipad', 'rt',
#               'link', 'link rt', 'app', 'time', 'line']

# %%
def encode(series, stopwords=stop_list):
    """
    Encodes a series into a bag of words series, removing stop words and URLS
    
    Parameters
    -----------------------------
    series[pd.Series]:
        A series of strings to be converted
    stop_list[list]:
        A list of stop words to be removed from the Series
    
    Returns
    -----------------------------
    series[pd.Series]:
        where "@Wesley83 3g iphone 3 hrs Tweeting http://google.com"
        = [wesley83, 3g, iphone, 3, hrs, tweeting]
        """
    series = series.replace('(http[^ ]*)|(www\.[^ ]*)', '', regex=True)
    series = series.str.replace("[^\w\s]", "").str.lower().copy()
    series = series.apply(lambda x: [i for i in x.split() if i not in stopwords])
    return series

# %%
# Training the Word2Vec model
data = encode(df['text'].copy())
model = Word2Vec(data, workers=-1)
model.train(data, total_examples=model.corpus_count, epochs=100)
wv = model.wv

# %% [markdown]
# ### Using Word2Vec
#
# > Explore word math more

# %%
pd.Series(dict(wv.most_similar(positive=['iphone'], negative=['android'], topn=20)))
# Out:
# late         0.393383
# awesomely    0.321381
# pop          0.314805
# 1            0.274874
# everyone     0.271949
# others       0.269912
# working      0.267606
# probably     0.263387
# called       0.261103
# ampipad      0.260160
# charge       0.258815
# 11           0.253011
# selling      0.252128
# push         0.251104
# hall         0.239309
# speech       0.237858
# stuff        0.231666
# fam          0.228060
# around       0.227327
# sxflip       0.217971
# dtype: float64

# %%
pd.Series(dict(wv.most_similar(positive=['android'], negative=['iphone'], topn=20)))
# Out:
# guide          0.304271
# exhibit        0.278210
# apple          0.274422
# employees      0.266980
# saves          0.265875
# lost           0.263514
# pay            0.263044
# autocorrect    0.259253
# congress       0.259095
# stock          0.257821
# apparently     0.242634
# whoa           0.242630
# booth          0.240879
# mind           0.236727
# food           0.235528
# worry          0.228749
# lot            0.225996
# purchase       0.222743
# learn          0.216431
# limited        0.215183
# dtype: float64

# %% [markdown]
# ### Generating a Word Cloud
# > * Split positive and negative emotion texts
# > * Encode the texts
# > * Create a mask image for the word cloud
# > * Use the ImageColorGenerator to color the words the same as the image's colors

# %%
data_positive = df.loc[df['emotion'] == 'Positive emotion']['text']
data_negative = df.loc[df['emotion'] == 'Negative emotion']['text']
data_positive = pd.DataFrame(encode(data_positive, stopwords=stop_list))
data_negative = pd.DataFrame(encode(data_negative, stopwords=stop_list))

# %%
positive_words = [i[0] for i in data_positive.explode('text').values]
negative_words = [i[0] for i in data_negative.explode('text').values]

# %%
positive_not_in_negative = [word for word in positive_words if word not in negative_words]
negative_not_in_positive = [word for word in negative_words if word not in positive_words]

# %%
mask = np.array(Image.open('images/phone.jpg'))

# %%
mask_colors = ImageColorGenerator(mask)

# %% [markdown]
# #### Generating

# %%
# Define the wordcloud
wordcloud = WordCloud(width = 1200, height = 1200, background_color='white',
                      min_font_size=10, mask=mask, color_func=mask_colors,
                      contour_color='black', contour_width=.5)

# Generate the wordcloud
wordcloud.generate(' '.join([' '.join(word) for word in data]))


# Plot and show the wordcloud
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0)

# %%
# Define and generate the wordcloud for positive words
wordcloud_p = WordCloud(width = 1200, height = 1200, background_color ='white',
                        min_font_size = 10, mask=mask, color_func=mask_colors,
                        random_state=42, contour_color='black', contour_width=.5)
wordcloud_p.generate(' '.join(positive_not_in_negative))

# Define and generate the wordcloud for negative words
wordcloud_n = WordCloud(width = 1200, height = 1200, background_color ='white',
                        min_font_size = 10, mask=mask, color_func=mask_colors,
                        random_state=42, contour_color='black', contour_width=.5)
wordcloud_n.generate(' '.join(negative_not_in_positive))

# Define subplots for both wordclouds
fig, (ax1, ax2) = plt.subplots(figsize=(10, 8), facecolor=None, ncols=2)

# Define the font for the titles
font = {'family': 'fantasy',
        'color':  'green',
        'weight': 'normal',
        'size': 40,
        }

# Plot positive cloud
ax1.imshow(wordcloud_p)
ax1.set_title("Positive", fontdict=font)
ax1.axis("off")

# Plot negative cloud
ax2.imshow(wordcloud_n)
font['color'] = 'red'
ax2.set_title("Negative", fontdict=font)
ax2.axis("off")
plt.tight_layout(pad = 0)

# %%
df.loc[df['text'].str.contains('fun')]['emotion'].value_counts(1)
# Out:
# Positive emotion    0.963636
# Negative emotion    0.036364
# Name: emotion, dtype: float64

# %%
df.loc[df['text'].str.contains('music')]['emotion'].value_counts(1)
# Out:
# Positive emotion    0.96875
# Negative emotion    0.03125
# Name: emotion, dtype: float64

# %%
df.loc[df['text'].str.contains('autocorrect')]['emotion'].value_counts(1)
# Out:
# Negative emotion    1.0
# Name: emotion, dtype: float64

# %% [markdown]
# ## Scrubbing the Data for Modeling
# > * One hot encode emotion to 1 and 0
# > * Train test split the data
# > * Fix class imbalance
# > * Vectorize the text data

# %% [markdown]
# ### Mapping emotion positive=1, negative=0

# %%
df['text'] = data.map(lambda x: ' '.join(x))
df.head()
# Out:
#                                                 text         directed_at  \
# 0  wesley83 3g iphone 3 hrs tweeting rise_austin ...              iPhone
# 1  jessedee know fludapp awesome ipadiphone app y...  iPad or iPhone App
# 2              swonderlin wait ipad 2 also sale sxsw                iPad
# 3  sxsw hope years festival isnt crashy years iph...  iPad or iPhone App
# 4  sxtxstate great stuff fri sxsw marissa mayer g...              Google
#
#             emotion
# 0  Negative emotion
# 1  Positive emotion
# 2  Positive emotion
# 3  Negative emotion
# 4  Positive emotion

# %%
df['emotion'] = df['emotion'].map({"Negative emotion": 0, "Positive emotion": 1})

# %% [markdown]
# ### Train Test Split

# %%
X = df['text'].copy()
y = df['emotion'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=.25)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((2661,), (2661,), (887,), (887,))

# %% [markdown]
# ### Fix class imbalance for training data
# > (83% - 16%) --> (50% - 50%)
#
# > Try using class weights in the model

# %%
df_train = pd.concat([X_train, y_train], axis=1)
df_train['emotion'].value_counts(1)
# Out:
# 1    0.837279
# 0    0.162721
# Name: emotion, dtype: float64

# %%
# split the majority and minority classes
emotion_majority = df_train[df_train.emotion==1]
emotion_minority = df_train[df_train.emotion==0]
 
# resample minority class
sample_count = len(emotion_majority)
df_train_minority = resample(emotion_minority,
                             n_samples=sample_count,
                             random_state=42)

# recombine the classes into X_train
df_train = pd.concat([emotion_majority, df_train_minority])
df_train.emotion.value_counts(1)
# Out:
# 1    0.5
# 0    0.5
# Name: emotion, dtype: float64

# %%
X_train = df_train['text'].copy()
y_train = df_train['emotion'].copy()

# %% [markdown]
# ### Vectorize

# %%
tokenizer = nltk.tokenize.TweetTokenizer(preserve_case=False)
vectorizer = TfidfVectorizer(use_idf=True, tokenizer=tokenizer.tokenize,
                             stop_words=stop_list)

# %%
X_train_idf = vectorizer.fit_transform(X_train)
X_test_idf = vectorizer.transform(X_test)

# %%
X_train_idf, X_test_idf
# Out:
# (<4456x5555 sparse matrix of type '<class 'numpy.float64'>'
#  	with 53562 stored elements in Compressed Sparse Row format>,
#  <887x5555 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9660 stored elements in Compressed Sparse Row format>)

# %% [markdown]
# ## Modeling
# > We will be running a GridSearchCV to find the best params for each model. Scoring will be on accuracy of the following models:
# >- **Random Forest Classifier**
# >- **Gradient Boosting Classifier**
# >- **kNN** ( K-Nearest Neighbors Classifier )
# >- **SVC** ( Support Vector Machine )
# >- **Adaboost Classfier**
# >  - Will need to vectorized data that is not class balanced, because **adaboost** is for class imbalance.
# >- **Stacking Classfier**

# %% [markdown]
# ### Functions

# %%
def cust_classification_report(estimator, X, y, X_test, y_test,
                               classes=['Negative',
                                        'Positive'],
                               return_axes=False):
    """
    Scores the model, and plots a confusion matrix for the train and test
    data
    
    Parameters
    ----------------------------------------
    estimator[sklearn.Classfier]::
        The estimator that the classfication report is made for.
    X[Series or Matrix]::
        The features to predict with that the estimator was trained on.
    y[Series or Matrix]::
        The labels that will be predicted that the estimator was trained on.
    X_test[Series or Matrix]::
        The test features to predict with.
    y_test[Series or Matrix]::
        The test labels that will be predicted.
    classes[list]::
        A list of classes for the labels on the confusion matrices
    return_axes[bool]:: Default (False)
        Whether or not to return the fig and axes
    
    Returns if return_axes
    ----------------------------------------
    fig, axes
        The figure, and two axes of the confusion matrices
    
    """
    print("Training score:\n", estimator.score(X, y))
    print("="*20)
    print("Testing score:\n", estimator.score(X_test, y_test))
    print("="*20)
    fig, (ax1, ax2) = plt.subplots(figsize=(15, 6), ncols=2)
    ax1.set_title("Training data")
    plt.rcParams.update({'font.size': 16})
    plot_confusion_matrix(estimator, X, y, ax=ax1, cmap='Blues',
                          normalize='true', display_labels=classes)
    ax1.set_yticklabels(ax1.get_yticklabels(), rotation=90)
    ax2.set_title("Testing data")
    plot_confusion_matrix(estimator, X_test, y_test, ax=ax2, cmap='Blues',
                          normalize='true', display_labels=classes)
    ax2.set_yticklabels(ax2.get_yticklabels(), rotation=90)
    if return_axes:
        return fig, (ax1, ax2)

# %%
def grid_search(estimator, X, y, X_test, y_test,
                params={}, scoring='accuracy', verbose=True):
    """
    Models using GridSearchCV to find the best params for a specific model

    Parameters
    ----------------------------------------
    estimator[sklearn.Classfier]::
        The estimator that the classfication report is made for.
    X[Series or Matrix]::
        The features to predict with that the estimator was trained on.
    y[Series or Matrix]::
        The labels that will be predicted that the estimator was trained on.
    X_test[Series or Matrix]::
        The test features to predict with.
    y_test[Series or Matrix]::
        The test labels that will be predicted.
    params[dict]::
        parameters to test the model on
    scoring[str]::
        the mode of scoring to use see:
        https://scikit-learn.org/stable/modules/model_evaluation.html
    verbose[bool]::
        Whether to print out the classification report of the best model,
        and the params used    
    
    Returns
    ----------------------------------------
    clf_best[]::
        The best model that was found from the search
    """
    clf = GridSearchCV(estimator, params, scoring=scoring,
                       n_jobs=-1, cv=5)
    clf.fit(X, y)
    clf_best = clf.best_estimator_
    clf_best.fit(X, y)
    if verbose:
        print("Estimator:")
        print(clf.best_estimator_)
        print("="*20)
        cust_classification_report(clf_best, X, y, X_test, y_test)
    return clf_best

# %% [markdown]
# ### Random Forest
# > 1. Train a base model
# > - Define hyper-parameters for classifier
# > - Train and visualize results using grid_search with Random Forest Classifier

# %% [markdown]
# #### Vanilla Model

# %%
rf = RandomForestClassifier(max_depth=7)
rf.fit(X_train_idf, y_train)
cust_classification_report(rf, X_train_idf, y_train, X_test_idf, y_test)
# Out:
# Training score:
#  0.8451526032315978
# ...
# Testing score:
#  0.7519729425028185
# ...

# %% [markdown]
# #### Tuned Model

# %%
params = {
    'max_depth': [6],
}

if RETEST:
    params = {
        "n_estimators": [50, 100],
        'max_depth': [2, 4, 6],
        "min_samples_split": [2, 4, 6, 12, 24],
        'criterion': ['gini', 'entropy']
    }

# %%
rf_best = grid_search(
              RandomForestClassifier(random_state=42), 
              X_train_idf, y_train, X_test_idf, y_test, params,
              scoring='recall_macro')
# Out:
# Estimator:
# RandomForestClassifier(max_depth=6, random_state=42)
# ...
# Training score:
#  0.8276481149012568
# ...
# Testing score:
#  0.7609921082299888
# ...

# %% [markdown]
# <div class="shadow alert alert-info">
#     <ul><b>From the model:</b>
# <li>Not Overfitting as it's 82.7% accurate on training data</li>
# <li>71% and 77% true predictions,  much better than flipping a coin, and very balanced</li>
# <li>We may be able to tune more, and improve the training data, and hopefully improving the testing data in turn</li>
# </ul>
# </div>

# %% [markdown]
# ### Gradient Boosting Classifier
# > 1. Train a base model
# > - Define hyper-parameters for classifier
# > - Train and visualize results using grid_search with Gradient Boosting Classifier

# %% [markdown]
# #### Vanilla model

# %%
gb = GradientBoostingClassifier()
gb.fit(X_train_idf, y_train)
cust_classification_report(gb, X_train_idf, y_train, X_test_idf, y_test)
# Out:
# Training score:
#  0.8527827648114902
# ...
# Testing score:
#  0.7226606538895152
# ...

# %% [markdown]
# #### Tuned Model

# %%
params = {
    "n_estimators": [200],
    "learning_rate": [0.2],
    "min_samples_split": [0.6]
}

if RETEST:
    params = {
        "n_estimators": [100, 150, 200],
        "learning_rate": [0.05, 0.1, 0.15, 0.2],
        "min_samples_split": [0.4, 0.5, 0.6]
    }

# %%
gb_best = grid_search(GradientBoostingClassifier(random_state=42),
                      X_train_idf, y_train,
                      X_test_idf, y_test,
                      params, scoring='recall_micro')
# Out:
# Estimator:
# GradientBoostingClassifier(learning_rate=0.2, min_samples_split=0.6,
#                            n_estimators=200, random_state=42)
# ...
# Training score:
#  0.9405296229802513
# ...
# Testing score:
#  0.7914317925591883
# ...

# %% [markdown]
# <div class="shadow alert alert-info">
#     <ul><b>From the model:</b>
# <li>Slightly overfitting the training data</li>
# <li>Odd that the True Label(1) doesn't add up to 100%</li>
# <li>The best model overall at 79% accuracy</li>
# <li>Successfully predicting 64% and 82% of Negatives and Positives respectively</li>
# </ul>
# </div>

# %% [markdown]
# ### KNN Classifier
# > 1. Train a base model
# > - Define hyper-parameters for classifier
# > - Train and visualize results using grid_search with K-Nearest Neighbors Classifier

# %% [markdown]
# #### Vanilla model

# %%
knn = KNeighborsClassifier()
knn.fit(X_train_idf, y_train)
cust_classification_report(knn, X_train_idf, y_train, X_test_idf, y_test)
# Out:
# Training score:
#  0.9351436265709157
# ...
# Testing score:
#  0.7677564825253664
# ...

# %% [markdown]
# #### Tuned Model

# %%
params = {
    "n_neighbors": [6],
    "metric": ['manhattan']
}

if RETEST:
    params = {
        "n_neighbors": [6, 8, 10],
        "weights": ['uniform'],
        "p": [2, 5],
        "metric": ['euclidean', 'manhattan']
    }

# %%
knn_best = grid_search(KNeighborsClassifier(), X_train_idf, y_train,
                       X_test_idf, y_test, params,
                       scoring='accuracy')
# Out:
# Estimator:
# KNeighborsClassifier(metric='manhattan', n_neighbors=6)
# ...
# Training score:
#  0.9313285457809695
# ...
# Testing score:
#  0.7666290868094702
# ...

# %% [markdown]
# <div class="shadow alert alert-info">
#     <ul><b>From the model:</b>
# <li>Overfitting Negatives on training data</li>
# <li>Predicting 57% and 80% of Negatives and Positives Respectively</li>
# <li>77% accuracy on the Testing data</li>
# <li>Better than flipping a coin, but worse than Gradient Boosting Classifier</li>
# </ul>
# </div>

# %% [markdown]
# ### SVC Classifier
# > 1. Train a base model
# > - Define hyper-parameters for classifier
# > - Train and visualize results using grid_search with Support Vector Machine

# %% [markdown]
# #### Vanilla model

# %%
svc = svm.SVC(random_state=42)
svc.fit(X_train_idf, y_train)
cust_classification_report(svc, X_train_idf, y_train, X_test_idf, y_test)
# Out:
# Training score:
#  0.9988779174147218
# ...
# Testing score:
#  0.8838782412626832
# ...

# %% [markdown]
# #### Tuned Model

# %%
params = {
    'C': [1.5],
    'kernel': ['sigmoid']}

if RETEST:
    params = {'C': [0.5, 1, 1.5],
          'gamma': ['scale', 'auto'],
          'kernel': ['sigmoid']}

# %%
svc_best = grid_search(svm.SVC(random_state=42, probability=True),
                       X_train_idf, y_train, X_test_idf, y_test,
                       params, scoring='accuracy')
# Out:
# Estimator:
# SVC(C=1.5, kernel='sigmoid', probability=True, random_state=42)
# ...
# Training score:
#  0.9710502692998204
# ...
# Testing score:
#  0.830890642615558
# ...

# %% [markdown]
# <div class="shadow alert alert-info">
#     <ul><b>From the model:</b>
# <li>Overfitting the Training data, needs more tuning</li>
# <li>Predicting 66% and 86% of Negatives and Positives Respectively</li>
# <li>Suprisingly getting 83% accuracy on the Testing data which is better than the Gradient boosting, but the negative recall is suffering</li>
#         <li>The vanilla model seems to have better accuracy overall but low micro recall</li>
# </ul>
# </div>

# %% [markdown]
# ### Adaboost Classifier
# > 1. Train a base model
# > - Define hyper-parameters for classifier
# > - Train and visualize results using grid_search with Adaboost Classifier
# > - Adaboost also takes different base estimators so we will try out different estimators, and leave the best one
# >  >  Adaboost can be used for class imbalance, so we will be training it on the data that wasn't fixed for class imbalance
#
#
# **Just split the data before balancing**

# %% [markdown]
# #### Get data

# %%
df['emotion'].value_counts()
# Out:
# 1    2978
# 0     570
# Name: emotion, dtype: int64

# %%
X = df['text']
y = df.drop(['text', 'directed_at'], axis=1)

X_train_ada, X_test_ada, y_train_ada, y_test_ada = train_test_split(X, y, 
                                                                    random_state=42,
                                                                    test_size=.25)
X_train_ada.shape, y_train_ada.shape, X_test_ada.shape, y_test_ada.shape
# Out:
# ((2661,), (2661, 1), (887,), (887, 1))

# %%
tokenizer_ada = nltk.tokenize.TweetTokenizer(preserve_case=False)
vectorizer_ada = TfidfVectorizer(use_idf=True,
                                 tokenizer=tokenizer_ada.tokenize,
                                 stop_words=stop_list)

# %%
X_train_ada_idf = vectorizer_ada.fit_transform(X_train_ada)
X_test_ada_idf = vectorizer_ada.transform(X_test_ada)

# %% [markdown]
# #### Vanilla model

# %%
ada = AdaBoostClassifier(random_state=42)
ada.fit(X_train_idf, y_train)
cust_classification_report(ada, X_train_idf, y_train, X_test_idf, y_test)
# Out:
# Training score:
#  0.7877019748653501
# ...
# Testing score:
#  0.7294250281848929
# ...

# %% [markdown]
# #### Tuned Model

# %%
params = {
    "algorithm": ["SAMME.R"]
}

if RETEST:
    params = {
        "n_estimators": [5, 10, 20, 40, 80],
        "learning_rate": [0.001, 0.01, 0.1, 1],
        "algorithm": ["SAMME.R", "SAMME"]
    }

# %%
ada_best = grid_search(AdaBoostClassifier(rf_best, random_state=42),
                       X_train_ada_idf, y_train_ada,
                       X_test_ada_idf, y_test_ada,
                       params, scoring='accuracy')
# Out:
# Estimator:
# AdaBoostClassifier(base_estimator=RandomForestClassifier(max_depth=6,
#                                                          random_state=42),
#                    random_state=42)
# ...
# Training score:
#  0.9597895527996994
# ...
# Testing score:
#  0.8692220969560316
# ...

# %% [markdown]
# <div class="shadow alert alert-info">
#     <ul><b>From the model:</b>
# <li>Overfitting Negatives on training data needs more tuning</li>
# <li>Predicting 24% and 98% of Negatives and Positives Respectively</li>
# <li>86% accuracy on the Testing data</li>
# <li>Similar to the vanilla SVC classifier in that the macro recall is good, but the micro/Negative recall is suffering at 24%.  An estimator could get close to that accuracy simply predicting all as positive</li>
# </ul>
# </div>

# %% [markdown]
# ### Stacking classifier
# > 1. Train a base model using the base of each classfier we used before
# > - Train and visualize using the best estimators from each grid_search we did previously
# > - Test different combinations of classifiers, leave the best

# %% [markdown]
# #### Vanilla model

# %%
estimators = [
    ("knn", KNeighborsClassifier()),
    ("rf", RandomForestClassifier(random_state=42)),
    #("ada", AdaBoostClassifier(random_state=42)), Did not do well originally
    ("gb", GradientBoostingClassifier(random_state=42)),
    ("svc", svm.SVC(random_state=42))
]

# %%
stacking_clf = StackingClassifier(estimators, n_jobs=-1)
stacking_clf.fit(X_train_idf, y_train)
cust_classification_report(stacking_clf, X_train_idf, y_train, X_test_idf, y_test)
# Out:
# Training score:
#  0.999326750448833
# ...
# Testing score:
#  0.887260428410372
# ...

# %% [markdown]
# #### Tuned Model

# %%
estimators = [
    ("knn", knn_best),
    ("rf", rf_best),
    #("ada", ada_best),  Did not do well originally
    ("gb", gb_best),
    ("svc", svc_best)
]

# %%
stacking_clf_best = StackingClassifier(estimators, n_jobs=-1)
stacking_clf_best.fit(X_train_idf, y_train)
cust_classification_report(stacking_clf_best, X_train_idf, y_train, X_test_idf, y_test)
# Out:
# Training score:
#  0.9820466786355476
# ...
# Testing score:
#  0.8523111612175873
# ...

# %% [markdown]
# <div class="shadow alert alert-info">
#     <ul><b>From the model:</b>
# <li>Overfitting the training data at 98%</li>
# <li>Predicting 56% and 91% of Negatives and Positives Respectively</li>
# <li>86% accuracy on the Testing data</li>
# <li>Still struggling to predict the negative emotion,  slightly better than flipping a coin in that aspect</li>
# </ul>
# </div>

# %% [markdown]
# ### Voting Classfier?

# %% [markdown]
# #### Vanilla Model

# %%
estimators = [
    ("knn", KNeighborsClassifier()),
    ("rf", RandomForestClassifier(random_state=42)),
    ("ada", AdaBoostClassifier(random_state=42)),
    ("gb", GradientBoostingClassifier(random_state=42)),
    ("svc", svm.SVC(random_state=42))
]

# %%
vote_clf = VotingClassifier(estimators, n_jobs=-1)
vote_clf.fit(X_train_idf, y_train)
cust_classification_report(vote_clf, X_train_idf, y_train, X_test_idf, y_test)
# Out:
# Training score:
#  0.9824955116696589
# ...
# Testing score:
#  0.8579481397970687
# ...

# %% [markdown]
# #### Tuned Model

# %%
from itertools import combinations

# %%
estimators = [
    ("knn", KNeighborsClassifier()),
    ("rf", RandomForestClassifier(random_state=42)),
    ("ada", AdaBoostClassifier(random_state=42)),
    ("gb", GradientBoostingClassifier(random_state=42)),
    ("svc", svm.SVC(random_state=42))
]

# %%
param_estimators = list(combinations(estimators, 3))

# %%
params = {
    "estimators": [[('knn', KNeighborsClassifier()),
                  ('rf', RandomForestClassifier(random_state=42)),
                  ('svc', svm.SVC(random_state=42))]]
}

if RETEST:
    params = {
        "estimators": param_estimators
        }

# %%
param_estimators[0]
# Out:
# (('knn', KNeighborsClassifier()),
#  ('rf', RandomForestClassifier(random_state=42)),
#  ('ada', AdaBoostClassifier(random_state=42)))

# %%
vote_best = grid_search(VotingClassifier(estimators),
                       X_train_idf, y_train,
                       X_test_idf, y_test,
                       params, scoring='accuracy')
# Out:
# Estimator:
# VotingClassifier(estimators=[('knn', KNeighborsClassifier()),
#                              ('rf', RandomForestClassifier(random_state=42)),
#                              ('svc', SVC(random_state=42))])
# ...
# Training score:
#  0.9988779174147218
# ...
# Testing score:
#  0.895152198421646
# ...

# %% [markdown]
# <div class="shadow alert alert-info">
#     <ul><b>From the model:</b>
# <li>Maybe change to soft voting, and send in the weights of the respective models</li>
# <li>Good accuracy at 89.5%</li>
# <li>Overfitting the training data</li>
# </ul>
# </div>

# %% [markdown]
# ## Modeling Conclusion

# %% [markdown]
# **Estimator: Training Accuracy/ Testing Accuracy**
#
# * Random Forest: 82% / 76%
#
#
# * Gradient Boosting: 94% / 79%
#
#
# * KNN: 93% / 77%
#
#
# * SVC: 97% / 83%
#
#
# * AdaBoost: 96% / 87%
#
#
# * Stacking: 98% / 86%
#
#
# * Voting: 99.9% / 90%
#
# The Voting classifier is predicting at 90%, but fails on recall as it is missing 60% of the Negative tweets.  The Stacking classifier does slightly better at 56% of negative tweets, but the SVC does the best at 66% of the Negative tweets.  That is the model we will be using.

# %% [markdown]
# <div class="shadow alert alert-warning">
#     <ul><b>Chosen Model:</b>
#         <br></br>
#     We are going to be using the best tuned Support Vector Classifier <b>svc_best</b> for the feature importances as it had the best overall performance.  Some models had better accuracy, but they failed to predicted the negative tweets.
# </ul>
# </div>

# %%
svc_best
# Out:
# SVC(C=1.5, kernel='sigmoid', probability=True, random_state=42)

# %%
cust_classification_report(svc_best, X_train_idf, y_train, X_test_idf, y_test)
# Out:
# Training score:
#  0.9710502692998204
# ...
# Testing score:
#  0.830890642615558
# ...

# %% [markdown]
# ### Feature Importance
# > Based on this [Tutorial](https://towardsdatascience.com/explain-nlp-models-with-lime-shap-5c5a9f84d59b) from [Susan Li](https://medium.com/@actsusanli?source=post_page-----5c5a9f84d59b--------------------------------)

# %%
import shap

# %%
# Required by shap to enable javascript in the notebook
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
attrib_data = shap.sample(X_train_idf, 100, random_state=42)
f = lambda x: svc_best.predict_proba(x)
explainer = shap.KernelExplainer(f, attrib_data)
num_explanations = 20
shap_vals = explainer.shap_values(X_test_idf[:num_explanations])

# %%
words = vectorizer.vocabulary_
word_lookup = list()
for i in words.keys():
  word_lookup.append(i)
word_lookup = [''] + word_lookup
shap.summary_plot(shap_vals, feature_names=word_lookup, class_names=['Negative', 'Positive'])

# %%
df.loc[df['text'].str.contains('slower')]['emotion'].value_counts()
# Out:
# 1    1
# Name: emotion, dtype: int64

# %%
df.loc[df['text'].str.contains('fast')]['emotion'].value_counts()
# Out:
# 1    33
# 0    12
# Name: emotion, dtype: int64

# %% [markdown]
# ## Conclusion
#
# Rethink with new
#
# > * **Which model will perform best?**
# >  * Gradient Boosting for balanced recall, and stacking for the highest overall accuracy
#
# > * **Which aspects of a phone should the company improve?**
# >  * music quality
# >  * quality of their autocorrect
# >  * making the phones more fun
#
# > * **What can androids or iphones improve in their products to reduce negative feedback?**
# >  * Android
# >    * Interface
# >    * Ease of use
# >  * Iphone
# >    * Contests
# >    * Events

# %% [markdown]
# ### Future Work
#
# > * Build an sklearn pipeline with and grid search with the tokenizer and vectorizer parameters along with the parameters for each of the classifiers.
# > * Build neural networks for the data, using [Oscar](http://oscar.calldesk.ai/) for hyperparameter tuning
# > * More tuning on the above models

# %% [markdown]
# ## Appendix ( Experimental )

# %% [markdown]
# ### Modeling Neural Network

# %% [markdown]
# #### Functions

# %%
def evaluate_nn(model, history, X_train, y_train, X_test, y_test,
                classes=["Negative", "Positive"]):


    def make_confusion(y_true, y_pred, ax):
        cm = confusion_matrix(y_true, y_pred, normalize='true')
        cm_df = pd.DataFrame(cm,index=classes,columns=classes)
        sns.heatmap(cm_df, annot=True, cmap='Blues', ax=ax)
    
    
    def decorate_print(x):
        print('', "="*80,'\n',
              ' '*20, '   %s:\n'%x,
              '='*80)
    y_train_pred = model.predict(X_train).flatten().round()
    y_test_pred = model.predict(X_test).flatten().round()
    decorate_print("Classification Report (Test Data)")
    report = classification_report(y_test, y_test_pred, target_names=classes)
    report = '\n' + report
    print(report.replace('\n', '\n' + ' '*20))
    decorate_print("Confusion Matrices")
    fig, (ax1, ax2) = plt.subplots(figsize=(15, 6), ncols=2)
    
    # Train data confusion matrix
    make_confusion(y_train, y_train_pred, ax1)
    ax1.set_title("Training data")

    # Test data confusion matrix
    make_confusion(y_test, y_test_pred, ax2)
    ax2.set_title("Testing data")

    plt.show()
    decorate_print("History of loss and accuracy graphs")
    
    df = pd.DataFrame(history.history)
    
    fig, (ax3, ax4) = plt.subplots(figsize=(15, 6), ncols=2)

    df[[col for col in df.columns if 'acc' in col]].plot(ax=ax3)
    ax3.set_title("Accuracy")
    
    df[[col for col in df.columns if 'loss' in col]].plot(ax=ax4)
    ax4.set_title("Loss")

# %%
new_df = pd.concat([X, y], axis=1)
new_df.head()
# Out:
#                                                 text  emotion
# 0  wesley83 3g iphone 3 hrs tweeting rise_austin ...        0
# 1  jessedee know fludapp awesome ipadiphone app y...        1
# 2              swonderlin wait ipad 2 also sale sxsw        1
# 3  sxsw hope years festival isnt crashy years iph...        0
# 4  sxtxstate great stuff fri sxsw marissa mayer g...        1

# %%
text_data = new_df['text'].tolist()
y_t = new_df['emotion'].values
tokenizer = text.Tokenizer()
tokenizer.fit_on_texts(text_data)
X_t = tokenizer.texts_to_sequences(text_data)
X_t = sequence.pad_sequences(X_t)
MAX_SEQUENCE_LENGTH = X_t.shape[1]

# word_index = tokenizer.index_word
# reverse_index = {v:k for k,v in word_index.items()}

# %%
X_train, X_test, y_train, y_test = train_test_split(X_t, y_t, random_state=42)
X_train.shape, y_train.shape
# Out:
# ((2661, 22), (2661,))

# %% [markdown]
# #### Modeling

# %%
min_delta = new_df['emotion'].value_counts(1)[0]
min_delta
# Out:
# 0.16065388951521983

# %%
MAX_SEQUENCE_LENGTH = X_train.shape[1]
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index)+1,
                    input_length=MAX_SEQUENCE_LENGTH,output_dim=128))
#model.add(Input(shape=X_train.shape))
model.add(LSTM(64, activation='relu'))
model.add(Dropout(.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(.3))
# model.add(Dense(4, activation='relu'))
# model.add(Dropout(.3))
#model.add(Dense(8, activation='relu'))
#model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# model.add(Embedding())
# model.add(Dense(32, activation='relu', input_shape=X_train.shape))
# model.add(Dense(2, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['acc'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, 22, 128)           828416
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                49408
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# ...
# Total params: 882,049
# Trainable params: 882,049
# Non-trainable params: 0
# ...

# %%
earlystopping = EarlyStopping(monitor='val_acc', patience=3)
                              #min_delta=min_delta, mode='max')

history = model.fit(X_train, y_train, batch_size=64, epochs=100,
                    validation_split=0.2, callbacks=[earlystopping])
evaluate_nn(model, history, X_train, y_train, X_test, y_test)
# Out:
# Train on 2128 samples, validate on 533 samples
# Epoch 1/100
# 2128/2128 [==============================] - 2s 1ms/sample - loss: 0.5184 - acc: 0.8148 - val_loss: 0.3635 - val_acc: 0.8630
# Epoch 2/100
# 2128/2128 [==============================] - 1s 460us/sample - loss: 0.3699 - acc: 0.8308 - val_loss: 0.3369 - val_acc: 0.8630
# Epoch 3/100
# 2128/2128 [==============================] - 1s 440us/sample - loss: 0.2737 - acc: 0.8435 - val_loss: 0.3174 - val_acc: 0.8893
# Epoch 4/100
# 2128/2128 [==============================] - 1s 448us/sample - loss: 0.1946 - acc: 0.9253 - val_loss: 0.6990 - val_acc: 0.8968
# Epoch 5/100
# 2128/2128 [==============================] - 1s 449us/sample - loss: 0.1325 - acc: 0.9610 - val_loss: 0.4030 - val_acc: 0.8705
# Epoch 6/100
# 2128/2128 [==============================] - 1s 441us/sample - loss: 0.0782 - acc: 0.9718 - val_loss: 0.9501 - val_acc: 0.8743
# Epoch 7/100
# ...

# %% [markdown]
# ### Using Glove
#
# ADD RECREATE QUESTION

# %%
# Execution time ~= 5+
#glove_file = "/Users/12147/Datasets/glove.twitter.27B/glove.twitter.27B.200d.txt"
output_file = "./data/glove_to_vec.txt"
#glove2word2vec(glove_file, output_file)
glovew2v_model = KeyedVectors.load_word2vec_format(output_file)
wvg = glovew2v_model.wv

# %%
wvg.get_keras_embedding()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\anaconda3\envs\tf-gpu\lib\site-packages\keras\__init__.py in <module>
#       2 try:
# ----> 3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
#
# ImportError: cannot import name 'RandomRotation' from 'tensorflow.keras.layers.experimental.preprocessing' (C:\Users\12147\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow_core\python\keras\api\_v2\keras\layers\experimental\preprocessing\__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\anaconda3\envs\tf-gpu\lib\site-packages\gensim\models\keyedvectors.py in get_keras_embedding(self, train_embeddings, word_index)
#    1418         try:
# -> 1419             from keras.layers import Embedding
# ...

# %% [markdown]
# #### Model with glove

# %%
model = Sequential()
model.add(wvg.get_keras_embedding())

model.add(LSTM(64, activation='relu'))
model.add(Dropout(.1))
model.add(Dense(64, activation='relu'))
model.add(Dropout(.1))
# model.add(Dense(64, activation='relu'))
# model.add(Dropout(.1))
# model.add(Dense(1, activation='relu'))
# model.add(Dropout(.1))


model.add(Dense(1, activation='sigmoid'))
# model.add(Embedding())
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['acc'])
model.summary()

earlystopping = EarlyStopping(monitor='val_acc', patience=7, restore_best_weights=True,
                              min_delta=min_delta)
history = model.fit(X_train, y_train, batch_size=32, epochs=100,
                    validation_split=0.2, callbacks=[earlystopping])
evaluate_nn(model, history, X_train, y_train, X_test, y_test)
